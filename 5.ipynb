# %% [markdown]
# ### Question 1

# %%
import math

# %%
# Последовательности
a1 = [9.577, 12.628, 11.003, 12.512]
a2 = [12.718, 6.167, 9.919, 12.095, 5.811, 5.706]
a3 = [12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]
a4 = [11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]

# %% [markdown]
# ### Question 2

# %%
# Функция для расчета среднего значения выборки
def mean_sample(data):
    return sum(data) / len(data)

# Функция для расчета среднего значения квадратов выборки
def mean_of_squares_sample(data):
    return sum(x**2 for x in data) / len(data)

# Функция для расчета дисперсии выборки
def unbiased_sample_variance(data, mean_sample, mean_of_squares_sample):
    N = len(data)
    if N < 2:
        return None
    return (N / (N - 1)) * (mean_of_squares_sample - mean_sample**2)

# Функция для расчета стандартного отклонения
def standard_deviation(variance_value):
    if variance_value is None or variance_value == 0:
        return None
    return math.sqrt(variance_value)

# %%
# Функция для расчета среднего значения, дисперсии и стандартного отклонения
def calculate_statistics(sequence):
    mean = mean_sample(sequence)
    mean_square = mean_of_squares_sample(sequence)
    variance = unbiased_sample_variance(sequence, mean, mean_square) 
    std_dev = standard_deviation(variance)
    return mean, variance, std_dev

# %%
import matplotlib.pyplot as plt

def draw_graph_mat_exp(n_values, mat_values, lower_bounds, upper_bounds, individual_means, p):
    # Рисование результатов
    plt.figure(figsize=(10, 6))
    plt.plot(n_values, mat_values, marker='o', linestyle='dashdot', label="M_s (Среднее математическое ожидание)", color="blue")
    plt.plot(n_values, lower_bounds, marker='o', linestyle='--',  label="M_min_i (Нижняя граница)", color="red")
    plt.plot(n_values, upper_bounds, marker='o', linestyle='--', label="M_max_i (Верхняя граница)", color="green")
    plt.plot(n_values, individual_means, marker='o', label="Mi (Индивидуальные средние значения)", color="purple")

    plt.xscale('linear')
    plt.yscale('linear')
    plt.xlabel('Ni (Размер выборки)')
    plt.ylabel('Мат ожидание')
    plt.title(f'Доверительные интервалы для мат ожидания для p = {p}')
    plt.legend()
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.show()


def draw_graph_std(n_values, individual_std, std_values, std_min_intervals, std_max_intervals, p):
    # Рисование результатов
    plt.figure(figsize=(10, 6))
    plt.plot(n_values, individual_std, marker='o', label='S_i (Расчетное ср. квад отклонение)')
    plt.plot(n_values, std_values, marker='o', linestyle='dashdot', label="Sc (Среднее квадратичное отклонение)", color="blue")
    plt.plot(n_values, std_min_intervals, marker='x', linestyle='--', label='S_min_i (Нижняя граница)')
    plt.plot(n_values, std_max_intervals, marker='x', linestyle='--', label='S_max_i (Верхняя граница)')
    plt.xscale('linear')
    plt.yscale('linear')

    plt.xlabel('Ni (Размер выборки)')
    plt.ylabel('Ср. квад отклонение')
    plt.title(f'Доверительные интервалы для ср.квад отклонения для p = {p}')
    plt.legend()
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)

    plt.show()

# %% [markdown]
# ### Question 3, 4, 5, 6, 7

# %%
from scipy.stats import norm, t
import scipy.stats as stats

# Определить уровень значимости
p_values = [0.1, 0.05, 0.02, 0.01]

for p in p_values:
    print(f"_______ГДЕ p={p}_________\n")
    
    # Вычисление статистики и доверительных интервалов для каждой последовательности
    lower_bounds = []
    upper_bounds = []
    individual_means = []

    std_min_intervals = []
    std_max_intervals = []
    individual_std = []

    for i, seq in enumerate([a1, a2, a3, a4], start=1):
        mean, variance, std_dev = calculate_statistics(seq)
        n = len(seq)

        individual_means.append(mean)
        individual_std.append(std_dev)
        
        print(f"Статистика для a{i} где n={n}:")
        print(f"  Среднее значение = {mean:.3f}")
        print(f"  Дисперсия = {variance:.3f}")
        print(f"  Средне квадратичное отклонения = {std_dev:.3f}")
        print()


        # Квантиль нормального распределения
        normal_quantile = norm.ppf(1 - p / 2)
        a_min = mean - normal_quantile * (std_dev / math.sqrt(n))
        a_max = mean + normal_quantile * (std_dev / math.sqrt(n))
        print(f"Квантиль нормального распределения для a{i} (seq={seq}) (p={p}): {normal_quantile:.3f} \n")
        print(f"a_min = {a_min}")
        print(f"a_max = {a_max} \n")

        # Хранение верхней и нижней квантилей
        lower_bounds.append(a_min)
        upper_bounds.append(a_max)

        # Квантиль распределения Стьюдента
        t_quantile = t.ppf(1 - p / 2, df=n - 1)
        a_min_t = mean - t_quantile * (std_dev / math.sqrt(n))
        a_max_t = mean + t_quantile * (std_dev / math.sqrt(n))
        print(f"Квантиль распределения Стьюдента для a{i} (seq={seq}): {t_quantile:.3f}\n")
        print(f"a_min_t = {a_min_t}")
        print(f"a_max_t = {a_max_t}\n")

        # Вычисление граничных квантилей для хи-квадрата
        chi2_upper = stats.chi2.ppf(1 - p / 2, df=n - 1)
        chi2_lower = stats.chi2.ppf(p / 2, df=n - 1)

        print(f"Последовательность a{i} с n = {n}")
        print(f"  Верхняя квантиль хи-квадрата (1 - p/2, n-1): {chi2_upper:.3f}")
        print(f"  Нижняя квантиль хи-квадрата (p/2, n-1): {chi2_lower:.3f}\n")

        
        # Вычисление доверительного интервала для дисперсии
        s_min_2 = ((std_dev**2) * (n - 1)) / chi2_upper
        s_max_2 = ((std_dev**2) * (n - 1)) / chi2_lower
        
        # Вычисление доверительного интервала для ср. квад отклонения
        s_a_min = math.sqrt(s_min_2)
        s_a_max = math.sqrt(s_max_2)
        
        std_min_intervals.append(s_a_min)
        std_max_intervals.append(s_a_max)


        print(f"Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a{i}:")
        print(f" s_min_2: {s_min_2:.3f}, s_max_2: {s_max_2:.3f}")
        print(f" s_a_min: {s_a_min:.3f}, s_a_max: {s_a_max:.3f}\n")


        
        print(f"______________________________________________________________________________________________________________________________________________\n")
        
    mean_values = sum(individual_means) / len(individual_means)
    mat_values = [mean_values] * 4

    # Вычисление M_s (среднее по 4-м выборкам ср.кв отклонение)
    std_avg = math.sqrt((3*(individual_std[0]**2) + 5*(individual_std[1]**2) + 9*(individual_std[2]**2) + 11*(individual_std[3]**2))/(4+6+10+12-4))
    std_values = [std_avg] * 4

    print(f"  Среднее математическое ожидание = {mean_values:.3f}")
    print(f"  Среднее стандартное отклонение = {std_avg:.3f}")


    n_values = [4, 6, 10, 12]

    draw_graph_mat_exp(n_values, mat_values, lower_bounds, upper_bounds, individual_means, p)
    draw_graph_std(n_values, individual_std, std_values, std_min_intervals, std_max_intervals, p)
# Out:
# _______ГДЕ p=0.1_________
#
# Статистика для a1 где n=4:
#   Среднее значение = 11.430
#   Дисперсия = 2.074
#   Средне квадратичное отклонения = 1.440
#
# Квантиль нормального распределения для a1 (seq=[9.577, 12.628, 11.003, 12.512]) (p=0.1): 1.645
#
# a_min = 10.245603922225946
# a_max = 12.614396077774053
#
# Квантиль распределения Стьюдента для a1 (seq=[9.577, 12.628, 11.003, 12.512]): 2.353
#
# a_min_t = 9.73543315460714
# a_max_t = 13.12456684539286
#
# Последовательность a1 с n = 4
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 7.815
#   Нижняя квантиль хи-квадрата (p/2, n-1): 0.352
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a1:
#  s_min_2: 0.796, s_max_2: 17.683
#  s_a_min: 0.892, s_a_max: 4.205
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a2 где n=6:
#   Среднее значение = 8.736
#   Дисперсия = 10.575
#   Средне квадратичное отклонения = 3.252
#
# Квантиль нормального распределения для a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]) (p=0.1): 1.645
#
# a_min = 6.552306217862146
# a_max = 10.919693782137855
#
# Квантиль распределения Стьюдента для a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]): 2.015
#
# a_min_t = 6.06083879935893
# a_max_t = 11.411161200641072
#
# Последовательность a2 с n = 6
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 11.070
#   Нижняя квантиль хи-квадрата (p/2, n-1): 1.145
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a2:
#  s_min_2: 4.776, s_max_2: 46.160
#  s_a_min: 2.185, s_a_max: 6.794
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a3 где n=10:
#   Среднее значение = 10.442
#   Дисперсия = 15.591
#   Средне квадратичное отклонения = 3.949
#
# Квантиль нормального распределения для a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]) (p=0.1): 1.645
#
# a_min = 8.388528324926806
# a_max = 12.496221649677558
#
# Квантиль распределения Стьюдента для a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]): 1.833
#
# a_min_t = 8.15345832213628
# a_max_t = 12.731291652468084
#
# Последовательность a3 с n = 10
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 16.919
#   Нижняя квантиль хи-квадрата (p/2, n-1): 3.325
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a3:
#  s_min_2: 8.294, s_max_2: 42.201
#  s_a_min: 2.880, s_a_max: 6.496
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a4 где n=12:
#   Среднее значение = 11.821
#   Дисперсия = 12.643
#   Средне квадратичное отклонения = 3.556
#
# Квантиль нормального распределения для a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]) (p=0.1): 1.645
#
# a_min = 10.132284037755605
# a_max = 13.508925636567456
#
# Квантиль распределения Стьюдента для a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]): 1.796
#
# a_min_t = 9.977261670891941
# a_max_t = 13.66394800343112
#
# Последовательность a4 с n = 12
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 19.675
#   Нижняя квантиль хи-квадрата (p/2, n-1): 4.575
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a4:
#  s_min_2: 7.068, s_max_2: 30.399
#  s_a_min: 2.659, s_a_max: 5.514
#
# ______________________________________________________________________________________________________________________________________________
#
#   Среднее математическое ожидание = 10.607
#   Среднее стандартное отклонение = 3.477
# _______ГДЕ p=0.05_________
#
# Статистика для a1 где n=4:
#   Среднее значение = 11.430
#   Дисперсия = 2.074
#   Средне квадратичное отклонения = 1.440
#
# Квантиль нормального распределения для a1 (seq=[9.577, 12.628, 11.003, 12.512]) (p=0.05): 1.960
#
# a_min = 10.018705026495264
# a_max = 12.841294973504736
#
# Квантиль распределения Стьюдента для a1 (seq=[9.577, 12.628, 11.003, 12.512]): 3.182
#
# a_min_t = 9.138442344081955
# a_max_t = 13.721557655918044
#
# Последовательность a1 с n = 4
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 9.348
#   Нижняя квантиль хи-квадрата (p/2, n-1): 0.216
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a1:
#  s_min_2: 0.666, s_max_2: 28.832
#  s_a_min: 0.816, s_a_max: 5.370
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a2 где n=6:
#   Среднее значение = 8.736
#   Дисперсия = 10.575
#   Средне квадратичное отклонения = 3.252
#
# Квантиль нормального распределения для a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]) (p=0.05): 1.960
#
# a_min = 6.133968368658667
# a_max = 11.338031631341334
#
# Квантиль распределения Стьюдента для a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]): 2.571
#
# a_min_t = 5.323317267032941
# a_max_t = 12.14868273296706
#
# Последовательность a2 с n = 6
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 12.833
#   Нижняя квантиль хи-квадрата (p/2, n-1): 0.831
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a2:
#  s_min_2: 4.120, s_max_2: 63.612
#  s_a_min: 2.030, s_a_max: 7.976
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a3 где n=10:
#   Среднее значение = 10.442
#   Дисперсия = 15.591
#   Средне квадратичное отклонения = 3.949
#
# Квантиль нормального распределения для a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]) (p=0.05): 1.960
#
# a_min = 7.995065742233232
# a_max = 12.889684232371133
#
# Квантиль распределения Стьюдента для a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]): 2.262
#
# a_min_t = 7.617732196862864
# a_max_t = 13.2670177777415
#
# Последовательность a3 с n = 10
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 19.023
#   Нижняя квантиль хи-квадрата (p/2, n-1): 2.700
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a3:
#  s_min_2: 7.376, s_max_2: 51.963
#  s_a_min: 2.716, s_a_max: 7.209
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a4 где n=12:
#   Среднее значение = 11.821
#   Дисперсия = 12.643
#   Средне квадратичное отклонения = 3.556
#
# Квантиль нормального распределения для a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]) (p=0.05): 1.960
#
# a_min = 9.808846522035104
# a_max = 13.832363152287957
#
# Квантиль распределения Стьюдента для a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]): 2.201
#
# a_min_t = 9.561456081269554
# a_max_t = 14.079753593053507
#
# Последовательность a4 с n = 12
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 21.920
#   Нижняя квантиль хи-квадрата (p/2, n-1): 3.816
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a4:
#  s_min_2: 6.344, s_max_2: 36.446
#  s_a_min: 2.519, s_a_max: 6.037
#
# ______________________________________________________________________________________________________________________________________________
#
#   Среднее математическое ожидание = 10.607
#   Среднее стандартное отклонение = 3.477
# _______ГДЕ p=0.02_________
#
# Статистика для a1 где n=4:
#   Среднее значение = 11.430
#   Дисперсия = 2.074
#   Средне квадратичное отклонения = 1.440
#
# Квантиль нормального распределения для a1 (seq=[9.577, 12.628, 11.003, 12.512]) (p=0.02): 2.326
#
# a_min = 9.7548860248686
# a_max = 13.105113975131399
#
# Квантиль распределения Стьюдента для a1 (seq=[9.577, 12.628, 11.003, 12.512]): 4.541
#
# a_min_t = 8.160413838781286
# a_max_t = 14.699586161218713
#
# Последовательность a1 с n = 4
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 11.345
#   Нижняя квантиль хи-квадрата (p/2, n-1): 0.115
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a1:
#  s_min_2: 0.548, s_max_2: 54.182
#  s_a_min: 0.741, s_a_max: 7.361
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a2 где n=6:
#   Среднее значение = 8.736
#   Дисперсия = 10.575
#   Средне квадратичное отклонения = 3.252
#
# Квантиль нормального распределения для a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]) (p=0.02): 2.326
#
# a_min = 5.647560211562537
# a_max = 11.824439788437465
#
# Квантиль распределения Стьюдента для a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]): 3.365
#
# a_min_t = 4.268747354813877
# a_max_t = 13.203252645186124
#
# Последовательность a2 с n = 6
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 15.086
#   Нижняя квантиль хи-квадрата (p/2, n-1): 0.554
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a2:
#  s_min_2: 3.505, s_max_2: 95.391
#  s_a_min: 1.872, s_a_max: 9.767
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a3 где n=10:
#   Среднее значение = 10.442
#   Дисперсия = 15.591
#   Средне квадратичное отклонения = 3.949
#
# Квантиль нормального распределения для a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]) (p=0.02): 2.326
#
# a_min = 7.537580458272764
# a_max = 13.3471695163316
#
# Квантиль распределения Стьюдента для a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]): 2.821
#
# a_min_t = 6.919386211605776
# a_max_t = 13.965363762998589
#
# Последовательность a3 с n = 10
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 21.666
#   Нижняя квантиль хи-квадрата (p/2, n-1): 2.088
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a3:
#  s_min_2: 6.477, s_max_2: 67.207
#  s_a_min: 2.545, s_a_max: 8.198
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a4 где n=12:
#   Среднее значение = 11.821
#   Дисперсия = 12.643
#   Средне квадратичное отклонения = 3.556
#
# Квантиль нормального распределения для a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]) (p=0.02): 2.326
#
# a_min = 9.432780511615764
# a_max = 14.208429162707297
#
# Квантиль распределения Стьюдента для a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]): 2.718
#
# a_min_t = 9.0306972458275
# a_max_t = 14.61051242849556
#
# Последовательность a4 с n = 12
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 24.725
#   Нижняя квантиль хи-квадрата (p/2, n-1): 3.053
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a4:
#  s_min_2: 5.625, s_max_2: 45.544
#  s_a_min: 2.372, s_a_max: 6.749
#
# ______________________________________________________________________________________________________________________________________________
#
#   Среднее математическое ожидание = 10.607
#   Среднее стандартное отклонение = 3.477
# _______ГДЕ p=0.01_________
#
# Статистика для a1 где n=4:
#   Среднее значение = 11.430
#   Дисперсия = 2.074
#   Средне квадратичное отклонения = 1.440
#
# Квантиль нормального распределения для a1 (seq=[9.577, 12.628, 11.003, 12.512]) (p=0.01): 2.576
#
# a_min = 9.575244005818885
# a_max = 13.284755994181115
#
# Квантиль распределения Стьюдента для a1 (seq=[9.577, 12.628, 11.003, 12.512]): 5.841
#
# a_min_t = 7.224184987813365
# a_max_t = 15.635815012186635
#
# Последовательность a1 с n = 4
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 12.838
#   Нижняя квантиль хи-квадрата (p/2, n-1): 0.072
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a1:
#  s_min_2: 0.485, s_max_2: 86.750
#  s_a_min: 0.696, s_a_max: 9.314
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a2 где n=6:
#   Среднее значение = 8.736
#   Дисперсия = 10.575
#   Средне квадратичное отклонения = 3.252
#
# Квантиль нормального распределения для a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]) (p=0.01): 2.576
#
# a_min = 5.316350772954121
# a_max = 12.155649227045881
#
# Квантиль распределения Стьюдента для a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]): 4.032
#
# a_min_t = 3.3829610319039425
# a_max_t = 14.089038968096059
#
# Последовательность a2 с n = 6
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 16.750
#   Нижняя квантиль хи-квадрата (p/2, n-1): 0.412
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a2:
#  s_min_2: 3.157, s_max_2: 128.418
#  s_a_min: 1.777, s_a_max: 11.332
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a3 где n=10:
#   Среднее значение = 10.442
#   Дисперсия = 15.591
#   Средне квадратичное отклонения = 3.949
#
# Квантиль нормального распределения для a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]) (p=0.01): 2.576
#
# a_min = 7.2260654438520415
# a_max = 13.658684530752323
#
# Квантиль распределения Стьюдента для a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]): 3.250
#
# a_min_t = 6.384467480517824
# a_max_t = 14.500282494086541
#
# Последовательность a3 с n = 10
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 23.589
#   Нижняя квантиль хи-квадрата (p/2, n-1): 1.735
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a3:
#  s_min_2: 5.949, s_max_2: 80.880
#  s_a_min: 2.439, s_a_max: 8.993
#
# ______________________________________________________________________________________________________________________________________________
#
# Статистика для a4 где n=12:
#   Среднее значение = 11.821
#   Дисперсия = 12.643
#   Средне квадратичное отклонения = 3.556
#
# Квантиль нормального распределения для a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]) (p=0.01): 2.576
#
# a_min = 9.176706244822414
# a_max = 14.464503429500647
#
# Квантиль распределения Стьюдента для a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]): 3.106
#
# a_min_t = 8.63272376786921
# a_max_t = 15.008485906453851
#
# Последовательность a4 с n = 12
#   Верхняя квантиль хи-квадрата (1 - p/2, n-1): 26.757
#   Нижняя квантиль хи-квадрата (p/2, n-1): 2.603
#
# Доверительный интервал для дисперсии и ср. квад отклонения для последовательности a4:
#  s_min_2: 5.197, s_max_2: 53.422
#  s_a_min: 2.280, s_a_max: 7.309
#
# ______________________________________________________________________________________________________________________________________________
#
#   Среднее математическое ожидание = 10.607
#   Среднее стандартное отклонение = 3.477
